# %% [markdown]
# <a href="https://colab.research.google.com/github/dfigueroa13/data_science_1/blob/main/INMERSION_DATOS_AULA_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Primer encuentro de inmersión de datos

# %%
#from google.colab import drive

#drive.mount('/content/drive')

# %% [markdown]
# #Forma de abrir y mostrar contenidos en nuestro archivo .csv

# %%
import pandas as pd  #Se importa la libreria pandas con el alias 'pd' 

inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersión de Datos/inmuebles_bogota.csv') #Se usa la función read_csv() para leer el archivo .csv
inmuebles.head() #Se muestran las 5 primeras lineas para confirmar que es el archivo correcto
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape #Atributo shape permite mostrar el total de filas y columnas (filas,columnas)
# Out:
# (9520, 8)

# %%
inmuebles.columns #Atributo que muestra los nombres de las columnas
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos', 'Área':'Area'} #Se crea un diccionario para sustituir los nombres que puedan generar conflicto
inmuebles = inmuebles.rename(columns=columnas) #Se sustituye el nombre de las columnas al parametro columns
inmuebles.sample(5)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 8167  Apartamento         Apartamento en venta en Usaquén             2
# 8757  Apartamento         Apartamento en venta en Usaquén             3
# 6582  Apartamento        Apartamento en venta en Cedritos             2
# 6450  Apartamento   Apartamento en venta en Santa Barbara             2
# 4767  Apartamento  Apartamento en venta en Barrios Unidos             2
#
#       Banos  Area          Barrio                                    UPZ  \
# 8167      2    56         Usaquén                                Usaquén
# 8757      5   170         Usaquén                                Usaquén
# 6582      1    49        Cedritos                                Usaquén
# 6450      3    81   Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 4767      2    69  Barrios Unidos                              Los Andes
#
#                 Valor
# 8167    $ 300.000.000
# 8757  $ 1.100.000.000
# 6582    $ 265.000.000
# 6450    $ 400.000.000
# 4767    $ 420.000.000

# %%
#Resumen de variables, tipos, columnas, valores nulos o faltante
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]   #muestra la información de un dato por su numero de indice
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305] #Rango de datos
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300] #muestra el dato de la columna valor de la fila 300
type(inmuebles['Valor'][300:305]) #muestra el tipo de estructura
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean() #Obtiene el promedio de TODOS los datos en la columna AREA
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1217  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 3891  Apartamento            Apartamento en venta en Engativa             3
# 2596  Apartamento                Apartamento en venta en Suba             3
# 4156  Apartamento       Apartamento en venta en Santa Barbara             2
# 624   Apartamento          Apartamento en venta en Cantagallo             3
# ...           ...                                         ...           ...
# 3851         Casa                    Casa en venta en Kennedy             2
# 557   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8004  Apartamento                Apartamento en venta en Bosa             3
# 4477  Apartamento      Apartamento en venta en Quinta Camacho             1
# 704          Casa         Casa en venta en Zona Noroccidental             2
#
#       Banos  Area              Barrio                                    UPZ  \
# 1217      2    62  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 3891      1    53            Engativa                               Engativá
# 2596      3   121                Suba                                   Suba
# 4156      2    81       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 624       2    58          Cantagallo                               Britalia
# ...     ...   ...                 ...                                    ...
# 3851      1    51             Kennedy                        Kennedy Central
# 557       2    68  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 8004      1    55                Bosa                           Bosa Central
# 4477      1    40      Quinta Camacho     CHAPINERO: Chicó Lago + El Refugio
# 704       1    60  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
#
#               Valor
# 1217  $ 250.000.000
# 3891  $ 159.000.000
# 2596  $ 850.000.000
# 4156  $ 510.000.000
# 624   $ 311.000.000
# ...             ...
# 3851  $ 135.000.000
# 557   $ 323.000.000
# 8004  $ 130.000.000
# 4477  $ 410.000.000
# 704   $ 163.000.000
#
# [100 rows x 8 columns]

# %%
inmuebles.Barrio == 'Chico Reservado' #Muestra que inmuebles existen con el valor 'Chico reservado' dentro de Barrio, devuelve falsos y verdaderos
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum(inmuebles.Barrio == 'Chico Reservado') #Hace una suma del total de inmuebles en 'Chico Reservado'
# Out:
# 225

# %%
inmuebles_chico = inmuebles.Barrio == 'Chico Reservado' #Se asigna a la variable inmuebless_chico
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico] #Dentro de la variable se crea un dataframe con los inmuebles en el barrio chico
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean() #El area promedio de los inmuebles en chico reservado es menor que el general
# Out:
# 142.78666666666666

# %%
#Se usa len para ver la longitud del panda.series es decir el valor de con cuantos barrios contamos
#len(inmuebles.Barrio.value_counts()) 
#value_counts() que devuelve el conteo de cada aparición de barrio especifico
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.Barrio.value_counts()) #Cuantos UPZ tenemos en nuestro data set
# Out:
# 149

# %%
#Crear una grafica de barras con los conteos de cada inmueble por barrio
inmuebles_barrio =inmuebles.Barrio.value_counts()
inmuebles_barrio
#inmuebles_barrio.plot.bar()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
#Crear una grafica con los primeros 10 barrios con mas inmuebles
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# #**DESAFIO #1**
#
# 1. Calcular promedio de area de cada inmueble de todos los barrios y realizar un grafico del top 10 del promedio
#
# 2. Investigar y tomar el conteo, mediana, valor minimo, valor maximo de los atributos. Consultar como

# %%
median_inmuebles = inmuebles.Habitaciones.median() #Calcular la mediana
median_inmuebles
# Out:
# 3.0

# %%
min_inmuebles = inmuebles.Habitaciones.min() #Calcular el minimo de habitaciones de todos los inmuebles
min_inmuebles
# Out:
# 1

# %%
#max_inmuebles = inmuebles.Habitaciones.max()
max_inmuebles = inmuebles['Habitaciones'].max()   #Maximo de habitaciones

max_inmuebles
# Out:
# 110

# %%
barrios = inmuebles.Barrio.unique() 
barrios
# Out:
# array(['Zona Noroccidental', 'Castilla', 'Chico Reservado', 'Usaquén',
#        'Bella Suiza', 'El Chicó', 'Tintala', 'Marly', 'Kennedy',
#        'Nicolas De Federman', 'La Calleja', 'Mazuren', 'Suba',
#        'Barrios Unidos', 'Engativa', 'Fontibón', 'Villa Alsacia',
#        'Palermo', 'La Candelaria', 'El Contador', 'El Batán',
#        'Santa Barbara', 'Mirandela ', 'Cedritos', 'Colina Campestre',
#        'Hayuelos', 'Ciudad Salitre', 'Quinta Paredes',
#        'Candelaria La Nueva', 'Chico Norte', 'Normandia',
#        'Ciudad Bolívar', 'Bosa', 'Rafael Uribe Uribe', 'Las Villas',
#        'Modelia', 'San Patricio', 'Barrancas', 'Teusaquillo',
#        'Puente Aranda', 'Chapinero', 'Usme', 'Nueva Zelandia', 'Madelena',
#        'El Plan', 'Santa Paula', 'Villemar', 'Santa Fe', 'Antonio Nariño',
#        'La Uribe', 'Los Rosales', 'Chapinero Central', 'Los Mártires',
#        'Bogotá D.C', 'San Cristobal', 'Boyaca ', 'Timiza', 'Gran America',
#        'Costa Azul', 'Gran Granada', 'La Salle', 'Portales Del Norte',
#        'Cantagallo', 'Ciudad Berna', 'Villas De Granada', 'Santa Teresa',
#        'Eduardo Santos', 'Pasadena ', 'Florida Blanca', 'Metropolis',
#        'Galicia', 'Villa Maria', 'Puente Largo', 'La Estancia',
#        'Sotavento', 'Bosque De Pinos', 'Florencia', 'Bochica',
#        'Tunjuelito', 'El Salitre', 'La Granja', 'La Soledad ',
#        'Santa Ana', 'Capellania', 'Bellavista Occidental', 'Alhambra',
#        'Veraguas', 'El Retiro', 'El Refugio', 'Pontevedra ',
#        'Lagos De Cordoba', 'Parque Central Bavaria', 'San Luis',
#        'Quinta Camacho', 'Nueva Autopista', 'Casablanca', 'Las Nieves',
#        'La Macarena', 'Bosque Popular', 'Ciudadela Colsubsidio',
#        'San Antonio Norte', 'Chapinero Alto', 'Salitre ', 'Chico Navarra',
#        'Buenos Aires', 'Ricaurte', 'Restrepo', 'Las Aguas',
#        'Chico Norte Ii', 'Niza', 'Pinar De Suba', 'Estrada', 'El Virrey',
#        'Colinas De Suba', 'Gustavo Restrepo', 'Nueva Castilla',
#        'Quirigua', 'Los Lagartos', 'Bosa Porvenir', 'Bosa Piamonte',
#        'Andes Norte', 'Venecia', 'La Merced', 'San Diego', 'Libertador',
#        'Las Ferias', 'Santa Librada', 'Galerias', 'Gratamira', 'Alameda',
#        'San Cipriano', 'Cerros De Suba', 'Quiroga', 'Roma',
#        'La Estanzuela', 'La Sabana', 'Patio Bonito', 'Turingia',
#        'Las Cruces', 'Lago De Suba', 'Zona Franca', 'Ingles',
#        'El Castillo', 'Las Delicias', 'Verbenal', 'El Tunal',
#        'Santa Maria Del Lago', 'El Progreso', 'Prado Veraniego'],
#       dtype=object)

# %%
promedio_por_barrios= inmuebles.groupby('Barrio').Area.mean()
promedio_por_barrios.sort_values(ascending=False).head(10)
#promedio_por_barrios.sort_values(ascending=False).head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# #AULA 2

# %%
inmuebles.sample(20)
# Out:
#                      Tipo                                  Descripcion  \
# 4558          Apartamento              Apartamento en venta en Usaquén
# 6987          Apartamento          Apartamento en venta en Santa Paula
# 7515          Apartamento           Apartamento en venta en Las Nieves
# 4279          Apartamento             Apartamento en venta en Cedritos
# 4163          Apartamento             Apartamento en venta en Hayuelos
# 6813          Apartamento              Apartamento en venta en Usaquén
# 5992          Apartamento      Apartamento en venta en Chico Reservado
# 235           Apartamento             Apartamento en venta en Madelena
# 1602          Apartamento              Apartamento en venta en Usaquén
# 3022          Apartamento   Apartamento en venta en Zona Noroccidental
# 1566                 Casa                     Casa en venta en Kennedy
# 2636  Oficina/Consultorio  Oficina/Consultorio en venta en Los Rosales
# 1769          Apartamento             Apartamento en venta en Cedritos
# 8864                 Casa                 Casa en venta en Bella Suiza
# 8696          Apartamento            Apartamento en venta en Chapinero
# 5542          Apartamento        Apartamento en venta en Santa Barbara
# 3405          Apartamento              Apartamento en venta en Mazuren
# 6540          Apartamento          Apartamento en venta en Chico Norte
# 1946          Apartamento            Apartamento en venta en Chapinero
# 2941                 Casa                        Casa en venta en Bosa
#
#       Habitaciones  Banos  Area              Barrio  \
# 4558             3      3   128             Usaquén
# 6987             2      3    85         Santa Paula
# 7515             1      1    17          Las Nieves
# 4279             2      2    69            Cedritos
# 4163             3      2    58            Hayuelos
# 6813             2      3    90             Usaquén
# 5992             3      3   160     Chico Reservado
# 235              2      1    40            Madelena
# 1602             3      2   102             Usaquén
# 3022             3      2    68  Zona Noroccidental
# 1566             2      1    43             Kennedy
# 2636             1      1   250         Los Rosales
# 1769             2      2    69            Cedritos
# 8864            14      6   811         Bella Suiza
# 8696             1      1    36           Chapinero
# 5542             3      4   165       Santa Barbara
# 3405             3      2   120             Mazuren
# 6540             3      3   140         Chico Norte
# 1946             2      3   130           Chapinero
# 2941             3      1    47                Bosa
#
#                                          UPZ            Valor Moneda  \
# 4558                                 Usaquén    $ 590.000.000      $
# 6987   USAQUÉN: Country Club + Santa Bárbara    $ 519.000.000      $
# 7515  SANTA FE: Las Nieves + Sagrado Corazón    $ 190.000.000      $
# 4279                                 Usaquén    $ 330.000.000      $
# 4163                                 Modelia    $ 277.000.000      $
# 6813                                 Usaquén    $ 491.000.000      $
# 5992      CHAPINERO: Chicó Lago + El Refugio    $ 980.000.000      $
# 235                             Arborizadora    $ 177.500.000      $
# 1602                                 Usaquén    $ 609.800.000      $
# 3022      CHAPINERO: Pardo Rubio + Chapinero    $ 270.000.000      $
# 1566                         Kennedy Central    $ 116.000.000      $
# 2636      CHAPINERO: Chicó Lago + El Refugio  $ 2.755.500.000      $
# 1769                                 Usaquén    $ 518.000.000      $
# 8864   USAQUÉN: Country Club + Santa Bárbara  $ 6.400.000.000      $
# 8696      CHAPINERO: Pardo Rubio + Chapinero    $ 406.000.000      $
# 5542   USAQUÉN: Country Club + Santa Bárbara    $ 730.000.000      $
# 3405                                El Prado    $ 390.000.000      $
# 6540      CHAPINERO: Chicó Lago + El Refugio  $ 1.150.000.000      $
# 1946      CHAPINERO: Pardo Rubio + Chapinero    $ 900.000.000      $
# 2941                            Bosa Central    $ 120.800.000      $
#
#           Precio  Precio_Millon
# 4558   590000000          590.0
# 6987   519000000          519.0
# 7515   190000000          190.0
# 4279   330000000          330.0
# 4163   277000000          277.0
# 6813   491000000          491.0
# 5992   980000000          980.0
# 235    177500000          177.5
# 1602   609800000          609.8
# 3022   270000000          270.0
# 1566   116000000          116.0
# 2636  2755500000         2755.5
# 1769   518000000          518.0
# 8864  6400000000         6400.0
# 8696   406000000          406.0
# 5542   730000000          730.0
# 3405   390000000          390.0
# 6540  1150000000         1150.0
# 1946   900000000          900.0
# 2941   120800000          120.8

# %%
inmuebles.Valor[0].split() #split() separa una cadena en 2
# Out:
# ['$', '360.000.000']

# %%
#inmuebles.Valor.str.split() #Devuelve las cadenas de la columna valor cortadas en 2, en formato series
valor = inmuebles.Valor.str.split(expand=True) #expand=True lo devuelve en formato Data Frame
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] =valor[1]
inmuebles.sample(3)
# Out:
#       Tipo                      Descripcion  Habitaciones  Banos  Area  \
# 7560  Casa       Casa en venta en Chapinero            20      8   259
# 4456  Casa  Casa en venta en Barrios Unidos             6      6   394
# 5703  Casa      Casa en venta en Las Villas             4      3   239
#
#               Barrio                                 UPZ            Valor  \
# 7560       Chapinero  CHAPINERO: Pardo Rubio + Chapinero  $ 2.200.000.000
# 4456  Barrios Unidos                           Los Andes    $ 487.000.000
# 5703      Las Villas                                Niza    $ 920.000.000
#
#      Moneda         Precio
# 7560      $  2.200.000.000
# 4456      $    487.000.000
# 5703      $    920.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.000.000225.000.000148.000.000331.500.000300.000.0001.030.000.000195.000.000200.000.000168.000.000323.000.000275.000.000510.000.000176.000.000680.000.000680.000.000217.000.0001.050.000.000375.000.000458.000.0002.000.000.000425.000.000318.000.000660.000.000730.000.000140.000.000343.000.000385.000.0001.300.000.0001.195.000.000519.000.000350.000.000202.000.000429.000.000640.000.000435.000.000610.000.000650.000.000421.000.0001.300.000.000155.000.000530.000.000330.000.000225.000.000143.000.000245.500.000433.000.000315.000.000450.000.000350.000.000205.000.0001.200.000.000169.000.000375.000.000460.000.000308.000.0001.100.000.000400.000.000860.000.0001.650.000.000565.000.000238.000.000503.000.000330.000.000400.000.0001.650.000.000580.000.000503.000.000635.000.000499.000.000371.000.000179.000.000348.200.000238.000.000173.000.000257.000.0001.100.000.000298.500.000680.000.000680.000.000217.000.0001.050.000.000375.000.000660.000.000318.000.000458.000.000425.000.0002.000.000.000343.000.000730.000.000140.000.0001.300.000.000385.000.000369.000.000366.000.000378.000.000355.000.000700.000.000990.000.000600.000.000516.000.000350.000.000475.000.000749.000.0001.195.000.000498.000.000269.000.000153.000.000335.000.000399.000.000373.000.000415.000.0001.550.000.000460.000.000225.000.000200.000.000234.000.000199.000.000450.000.0001.400.000.000202.000.000350.000.000519.000.000310.000.000355.000.000545.000.000720.000.000650.000.000343.000.000127.000.000370.000.000162.000.0001.560.000.000136.000.000265.000.000131.000.000416.000.000161.000.000900.000.000389.000.000190.000.000139.000.000319.000.000327.000.000474.500.000308.000.000720.000.000310.000.000177.500.0001.200.000.000380.000.000210.000.0001.290.000.000320.000.000445.000.000340.000.000510.000.000465.000.000220.000.000337.000.000260.000.000445.000.000290.000.000342.514.000625.000.000490.000.000350.000.000444.150.000360.000.000370.000.000150.000.000232.500.000271.000.000450.000.000163.500.000390.000.000300.000.000406.000.000465.000.000390.000.000175.000.000445.000.000422.000.000690.000.000445.000.000357.000.000465.000.000164.000.000300.000.000406.000.0001.700.000.000570.000.000460.000.000960.000.000510.000.000520.000.000142.000.000750.000.000160.000.000445.000.000570.000.000319.981.523510.000.000380.000.000134.000.000120.000.000460.000.000560.000.000351.000.0001.390.000.000422.000.000260.000.000980.000.000116.100.000980.000.000237.000.000320.000.000530.000.000503.000.000117.000.0001.300.000.000477.000.000450.000.000515.000.000730.000.000600.000.000480.000.000560.000.000308.000.000365.000.0001.200.000.000371.000.000850.000.000428.000.000421.000.000650.000.000295.000.000144.000.000280.000.000162.000.000620.000.0001.200.000.000360.000.000350.000.000650.000.000560.000.000295.000.000413.500.0001.200.000.000370.000.000600.000.000390.000.000447.500.000132.000.000180.000.000285.000.000620.000.000400.000.0001.380.000.000335.238.800820.000.000545.000.000217.000.000495.000.000330.000.000570.000.000280.000.0002.000.000.000390.000.000311 ...

# %%
#Para eliminar los puntos dentro de los valores de la columna Precio
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles[['Precio','Barrio']]  #El doble corcheta indica que se desea una salida data frame
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
#Agregamos una nueva columna y convertimos el valor de precio a flotante y se agregan en dicha columna
inmuebles['Precio_Millon']=inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
wowers = inmuebles.Habitaciones == 110
habitacion_grande = inmuebles[wowers]
habitacion_grande
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[wowers] #loc[] sirve para localizar
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area ==2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=1000) #bins establece el rango a abarcar dentro del histograma //++bins -rango //--bins +rango
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

plt.figure(figsize=(10,6)) #Creación de lienzo //figsize permite elegir el valor del tamaño
grafica = sns.histplot(data=inmuebles, x='Precio_Millon',kde=True,hue='Tipo') #histplot permite agregar parametros a las graficas 
grafica.set_title('Distribución de valores de los inmuebles en Bogotá')
plt.xlim((50,1000)) #Se configura el limite minimo y maximo
#plt.ylim((0,20))
#plt.savefig('/content/drive/MyDrive/Inmersión de Datos/valor_inmuebles.png',format='png')
plt.show()

# %% [markdown]
# #Desafio 2
#
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (apartamento, casa, local, etc). Refinar el gráfico (Titulos, aumentar el tamaño de labels) Sacar conclusion de la información. Ejemplo: como esta el precio de apartamentos en relacion al de las fincas
#
# 2.Precio del m2 por barrio y utilizar la grafica que mas se adapte y hacer el gráfico más adecuado.
#
# Aun no existe la variable precio x m2 por lo que hay que dividir el precio por el area

# %% [markdown]
# #AGREGAR A GITHUB

# %%
# !apt-get  install git #Instalar git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
# !git clone <https://github.com/dfigueroa13/data_science_1.git> /content/drive/MyDrive/Inmersión de Datos
# Out:
# /bin/bash: https://github.com/dfigueroa13/data_science_1.git: No such file or directory
